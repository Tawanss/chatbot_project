# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawanss/chatbot_project/blob/main/Untitled33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
import pandas as pd

# %%
api_key = "AIzaSyApbF3errDSQXOC-d7JH_DC0FGTG1nKlpI"
genai.configure(api_key=api_key)

# %%
model_info = genai.get_model('models/gemini-1.5-flash')
(model_info.input_token_limit, model_info.output_token_limit)
# Out:
# (1000000, 8192)

# %%
model = genai.GenerativeModel('models/gemini-1.5-flash')
model.count_tokens("ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตรงตามที่หลักสูตรกำหนดหรือไม่- กรณีที่ลงทะเบียนตามหลักสูตรแล้ว : ให้นำรหัสนักศึกษา แจ้งได้ที่งานบริการการศึกษา สามารถติดต่อได้ที่ : งานบริการการศึกษาและพัฒนานักศึกษา, อาคาร SC.06 (ชั้น1) คณะวิทยาศาสตร์ มหาวิทยาลัยขอนแก่น- กรณีที่ไม่ได้ลงทะเบียนตามหลักสูตร : ให้สำรองที่นั่ง โดยกรอกแบบฟอร์มทางเว็ปไซต์ https://req.kku.ac.th/ ข้อมูลอ้างอิงจาก https://sc2.kku.ac.th/office/sc-service/index.php/th/2015-02-11-07-10-16")
# Out:
# total_tokens: 193

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/อ้างอิง chatbot/ตารางเปรียบเทียบเเชทบอทใหม่ - Sheet2.csv')

# %%
df.head()
# Out:
#   ประเภทเครื่องมือ                                              คำถาม  \
# 0           gemini  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 1       diglogflow  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 2           gemini              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 3       diglogflow              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 4           gemini                      ขอลงทะเบียนเรียนซ้ำได้เมื่อไร
#
#                                         คำตอบอ้างอิง  \
# 0  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 1  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 2  ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้รั...
# 3  "ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้ร...
# 4  "สามารถลงซ้ำได้ทุกภาคการศึกษา โดยต้องลงทะเบียน...
#
#                                            คำตอบจริง  token_count  relevant
# 0  การลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งสามา...          NaN       NaN
# ...

# %%
# สร้างฟังก์ชันสำหรับการนับ token
def count_tokens(text):
    return model.count_tokens(text)

# %%
df['คำตอบจริง'].fillna('สวัสดีครับ', inplace=True)
# Out:
# <ipython-input-9-6fd7c5ecbdbe>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['คำตอบจริง'].fillna('สวัสดีครับ', inplace=True)

# %%
df.head()
# Out:
#   ประเภทเครื่องมือ                                              คำถาม  \
# 0           gemini  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 1       diglogflow  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 2           gemini              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 3       diglogflow              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 4           gemini                      ขอลงทะเบียนเรียนซ้ำได้เมื่อไร
#
#                                         คำตอบอ้างอิง  \
# 0  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 1  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 2  ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้รั...
# 3  "ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้ร...
# 4  "สามารถลงซ้ำได้ทุกภาคการศึกษา โดยต้องลงทะเบียน...
#
#                                            คำตอบจริง  token_count  relevant
# 0  การลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งสามา...          NaN       NaN
# ...

# %%
# นับจำนวน token ในคอลัมน์ "คำตอบจริง" (สมมติว่าชื่อคอลัมน์คือ 'คำตอบจริง')
df['token_count'] = df['คำตอบจริง'].apply(count_tokens)

# %%
df.head()
# Out:
#   ประเภทเครื่องมือ                                              คำถาม  \
# 0           gemini  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 1       diglogflow  ขอลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งทำอย่...
# 2           gemini              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 3       diglogflow              ขอลงทะเบียนเกิน 22 หน่วยกิตได้หรือไม่
# 4           gemini                      ขอลงทะเบียนเรียนซ้ำได้เมื่อไร
#
#                                         คำตอบอ้างอิง  \
# 0  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 1  "ให้นักศึกษาตรวจสอบว่าตนเองได้ลงทะเบียนเรียนตร...
# 2  ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้รั...
# 3  "ได้ แต่ต้องติดต่อกับอาจารย์ที่ปรึกษาเพื่อได้ร...
# 4  "สามารถลงซ้ำได้ทุกภาคการศึกษา โดยต้องลงทะเบียน...
#
#                                            คำตอบจริง          token_count  \
# 0  การลงทะเบียนในรายวิชาที่ไม่ได้สำรองที่นั่งสามา...  total_tokens: 451\n
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
# โหลดโมเดล WangchanBERTa และ tokenizer
tokenizer = AutoTokenizer.from_pretrained("airesearch/wangchanberta-base-att-spm-uncased")
model = AutoModel.from_pretrained("airesearch/wangchanberta-base-att-spm-uncased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/905k [00:00<?, ?B/s]
# ...

# %%
# ฟังก์ชันสำหรับสร้าง embeddings จากข้อความ
def get_embeddings(text):
    text = str(text)
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state[:, 0, :].numpy()

# ฟังก์ชันในการคำนวณ Cosine Similarity ระหว่าง "คำตอบจริง" และ "คำตอบอ้างอิง"
def calculate_similarity(row):
    emb_คำตอบจริง = get_embeddings(row['คำตอบจริง'])
    emb_คำตอบอ้างอิง = get_embeddings(row['คำตอบอ้างอิง'])
    similarity = cosine_similarity(emb_คำตอบจริง, emb_คำตอบอ้างอิง)
    return similarity[0][0]

# %%
df['cosine_similarity'] = df.apply(calculate_similarity, axis=1)
